# %%
import os
import json

# Path to the data folder
data_folder = "./data/extracted/"

# %%
def cleaning_json_files(data_folder):
    """
    Process and clean shop data from multiple JSON files in a directory.
    
    Extracts shop entries from each file's 'docs' array, transforms hierarchical categories
    into flat lists, cleans keyword strings, and returns standardized shop records.
    
    Args:
        data_folder (str): Path to directory containing source JSON files
    
    Returns:
        list: Dictionaries with structured shop data containing:
            - title (str)
            - categories (list)
            - subcategories (list) 
            - level (dict)
            - keywords (list)
            - description (str)
    """
    # List all JSON files in the folder
    json_files = os.listdir(data_folder)

    # Shops list
    shops = []

    # Read each JSON file
    for file_name in json_files:
        file_path = os.path.join(data_folder, file_name)
        with open(file_path, 'r') as file:
            data = json.load(file)
            for datapoint in data['docs']:
                # Extracting shop details one-by-one
                store = {}
                store['title'] = datapoint['title']
                
                # Filtering categories and subcategories
                categories = []
                subcategories = []
                for category in datapoint['categoryTree']:
                    categories.append(category['title'])
                    
                    for sub in category['subs']:
                        subcategories.append(sub['title'])
                    
                store['categories'] = categories
                store['subcategories'] = subcategories
                
                # Storing venue
                store['venue'] = datapoint['venue']
                
                # Filtering and storing keywords as list
                keywords = []
                keywords_str = datapoint['keywords']
                for keyword in keywords_str.split(','):
                    if(keyword != '' and keyword != '&'):
                        keywords.append(keyword)
                store['keywords'] = keywords
                
                # Storing description of shop
                store['description'] = datapoint['text']
                
                shops.append(store)
                
    return shops

# %%
shops = cleaning_json_files(data_folder=data_folder)

with open('./data/shops.json', 'w') as json_file:
    json.dump(shops, json_file, indent=4)

# %%
import pandas as pd

df = pd.read_json('./data/shops.json')
df.head(10)
# Out:
#                        title                      categories  \
# 0                     GODIVA              [Food & Beverages]
# 1  GORDON RAMSAY BAR & GRILL              [Food & Beverages]
# 2  GRAND IMPERIAL RESTAURANT              [Food & Beverages]
# 3                 Gadget Hub             [Digital Lifestyle]
# 4                  GadgetHub             [Digital Lifestyle]
# 5                 Galaxy Ace                       [Fashion]
# 6          Galaxy Collection                [Toys & Hobbies]
# 7                Galaxy Gift  [Asian Avenue, Toys & Hobbies]
# 8     Garrett Popcorn Shops®              [Food & Beverages]
# 9                        Geb                       [Fashion]
#
#            subcategories                                       venue  \
# 0             [Desserts]                         GF.Ice Rink Railing
# 1              [Western]                  Lobby Level, Sunway Resort
# 2              [Chinese]  Suite 101, First Floor, The Pinnacle Annex
# 3     [Add-Ons, Gadgets]                           F1.705-2.PushCart
# 4                     []                                       F1.28
# 5  [Accessories, Unisex]                          LG2,M.057.PushCart
# 6                [Gifts]                          LG2,M.062.PushCart
# 7                [Gifts]                                    F1.AV.32
# 8         [Halal, Snack]                                  LG2.RINK.B
# 9               [Ladies]                                      LG1.77
#
#                                             keywords  \
# 0  [beverages, chocoholic, chocolatelover, desser...
# 1  [bar, beef wellington, beverages, british, cla...
# 2  [beverages, chinese restaurant, food & beverag...
# 3  [add-ons, digital lifestyle, gadget hub, gadge...
# 4  [bag, beauty light, cable, car grab, casing, c...
# 5    [accessories, ace, fashion, galaxy ace, unisex]
# 6  [collection, galaxy collection, gifts, hobbies...
# 7  [accessories, asian avenue, asianavenue, avenu...
# 8  [beverages, caramel, food & beverages, garrett...
# 9                   [bohemian, fashion, geb, ladies]
#
#                                          description
# 0  GODIVA is the world’s most iconic premium choc...
# 1  Gordon Ramsay Bar & Grill in Sunway City Kuala...
# 2  Established since 2008, we are Malaysia’s lead...
# 3
# 4  GadgetHub has always been a pioneer and at the...
# 5
# 6
# 7  Retailing of customized plate, accessories, so...
# 8  Garrett Popcorn Shops® - A Chicago Tradition f...
# 9  Retailing of fashion apparel and related acces...
